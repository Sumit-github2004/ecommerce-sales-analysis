# %%
#importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#loading the data in DataFrame

customers_raw = pd.read_csv("DimCustomers_dirty.csv")#cleaned
orders_raw = pd.read_csv("FactOrders_dirty.csv")#cleaned
sales_raw = pd.read_csv("FactSales_dirty.csv")#cleaned

products_raw = pd.read_csv("DimProducts_dirty.csv")

# %%
#making copies before cleaning

customers = customers_raw.copy()
orders = orders_raw.copy()
sales = sales_raw.copy()
products = products_raw.copy()

# %%
#printing rows and column numbers for each dataframe

print("="*50)
print("Total Rows and Columns in Each DataFrame")
print("="*50)
print("Customer Dataframe",customers.shape)
print("Order Dataframe",orders.shape)
print("Sales Dataframe",sales.shape)
print("Products Dataframe",products.shape)
# Out:
# ...
# Total Rows and Columns in Each DataFrame
# ...
# Customer Dataframe (12120, 9)
# Order Dataframe (32320, 7)
# Sales Dataframe (100000, 12)
# Products Dataframe (2030, 8)

# %%
customers.head()
# Out:
#   CustomerID          Name  Gender Age       City        State  SignupDate  \
# 0    C000001  Aditi Sharma    Male  46   Guwahati        Assam  2023-12-19
# 1    C000002    Aditya Rao    Male  18  Ahmedabad      Gujarat  2023-12-29
# 2    C000003   Arjun Reddy    Male  20     Mumbai  Maharashtra  2025-02-11
# 3    C000004   Sanya Kumar  Female  26     Mysuru    Karnataka  2026-04-27
# 4    C000005     Aarav Rao  Female  30    Chennai   Tamil Nadu  2024-05-25
#
#           Segment     Acquisition
# 0        Consumer  Organic Search
# 1        Consumer  Organic Search
# 2        Consumer        Referral
# 3  Small Business     Paid Search
# 4        Consumer           Email

# %%
customers.tail()
# Out:
#       CustomerID           Name  Gender Age    City        State  SignupDate  \
# 12115    C001014  Krishna Reddy  Female  27   Surat      Gujarat  2022-02-18
# 12116    C008337   Sneha Sharma    Male  21   Patna        Bihar  2022-03-24
# 12117    C011614   Tanya Das Jr    Male  18   Surat      Gujarat  2025-03-14
# 12118    C005233    Rahul Reddy  Female  30  Mysuru    Karnataka  2026-01-30
# 12119    C010947     Manish Das  Female  38    Pune  Maharashtra  2025-02-25
#
#         Segment  Acquisition
# 12115  Consumer        Email
# 12116  Consumer  Marketplace
# 12117  Consumer        Email
# 12118  Consumer  Paid Search
# 12119  Consumer  Paid Search

# %%
customers.columns
# Out:
# Index(['CustomerID', 'Name', 'Gender', 'Age', 'City', 'State', 'SignupDate',
#        'Segment', 'Acquisition'],
#       dtype='str')

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12120 entries, 0 to 12119
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerID   12120 non-null  str
#  1   Name         12074 non-null  str
#  2   Gender       12093 non-null  str
#  3   Age          12096 non-null  str
#  4   City         12074 non-null  str
#  5   State        12051 non-null  str
#  6   SignupDate   12077 non-null  str
#  7   Segment      12096 non-null  str
#  8   Acquisition  12065 non-null  str
# dtypes: str(9)
# memory usage: 852.3 KB

# %%
customers.describe(include="all")
# Out:
#        CustomerID        Name  Gender    Age   City        State  SignupDate  \
# count       12120       12074   12093  12096  12074        12051       12077
# unique      12000         835      11     62     98           56        1772
# top       C000072  Manish Das  Female     18   Pune  Maharashtra  2027-01-15
# freq            2          35    5835    995    547         1501          42
#
#          Segment     Acquisition
# count      12096           12065
# unique        10              13
# top     Consumer  Organic Search
# freq        7343            2913

# %%
customers.isna().sum()
# Out:
# CustomerID      0
# Name           46
# Gender         27
# Age            24
# City           46
# State          69
# SignupDate     43
# Segment        24
# Acquisition    55
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(60)

# %%
customers["Gender"].value_counts()
# Out:
# Gender
# Female        5835
# Male          5792
# Non-Binary     231
# male            34
# Unknown         33
# M               32
# FEMALE          32
# MALE            29
# female          28
# F               28
# N/B             19
# Name: count, dtype: int64

# %%
customers["Gender"] = customers["Gender"].str.title()

# %%
customers["Gender"].value_counts()
# Out:
# Gender
# Female        5895
# Male          5855
# Non-Binary     231
# Unknown         33
# M               32
# F               28
# N/B             19
# Name: count, dtype: int64

# %%
customers["Gender"] = customers["Gender"].replace("M" , "Male")

# %%
customers["Gender"].value_counts()
# Out:
# Gender
# Female        5895
# Male          5887
# Non-Binary     231
# Unknown         33
# F               28
# N/B             19
# Name: count, dtype: int64

# %%
customers["Gender"] = customers["Gender"].replace("F" , "Female")

# %%
customers["Gender"].value_counts()
# Out:
# Gender
# Female        5923
# Male          5887
# Non-Binary     231
# Unknown         33
# N/B             19
# Name: count, dtype: int64

# %%
customers["Gender"] = customers["Gender"].replace("N/B", "Non-Binary")

# %%
customers["Gender"].value_counts()
# Out:
# Gender
# Female        5923
# Male          5887
# Non-Binary     250
# Unknown         33
# Name: count, dtype: int64

# %%
customers["City"] = customers["City"].str.title()

# %%
customers["City"].isna().sum()
# Out:
# np.int64(46)

# %%
customers["City"] = customers["City"].fillna("Unknown")

# %%
customers["City"].isna().sum()
# Out:
# np.int64(0)

# %%
customers["Age"].isna().sum()
# Out:
# np.int64(24)

# %%
customers["Age"] = pd.to_numeric(customers["Age"], errors="coerce")

# %%
customers["Age"] = customers["Age"].fillna(customers["Age"].median())

# %%
customers["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
customers.head(1)
# Out:
#   CustomerID          Name Gender   Age      City  State  SignupDate  \
# 0    C000001  Aditi Sharma   Male  46.0  Guwahati  Assam  2023-12-19
#
#     Segment     Acquisition
# 0  Consumer  Organic Search

# %%
customers["State"] = customers["City"].str.title()

# %%
customers["Gender"] = customers["Gender"].fillna("Unknown")

# %%
customers["Age"] = customers["Age"].astype(int)

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12120 entries, 0 to 12119
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerID   12120 non-null  str
#  1   Name         12074 non-null  str
#  2   Gender       12120 non-null  str
#  3   Age          12120 non-null  int64
#  4   City         12120 non-null  str
#  5   State        12120 non-null  str
#  6   SignupDate   12077 non-null  str
#  7   Segment      12096 non-null  str
#  8   Acquisition  12065 non-null  str
# dtypes: int64(1), str(8)
# memory usage: 852.3 KB

# %%
customers["SignupDate"] = pd.to_datetime(
    customers["SignupDate"],
    format="mixed",
    errors="coerce"
)

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12120 entries, 0 to 12119
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerID   12120 non-null  str
#  1   Name         12074 non-null  str
#  2   Gender       12120 non-null  str
#  3   Age          12120 non-null  int64
#  4   City         12120 non-null  str
#  5   State        12120 non-null  str
#  6   SignupDate   12050 non-null  datetime64[us]
#  7   Segment      12096 non-null  str
#  8   Acquisition  12065 non-null  str
# dtypes: datetime64[us](1), int64(1), str(7)
# memory usage: 852.3 KB

# %%
customers.isna().sum()
# Out:
# CustomerID      0
# Name           46
# Gender          0
# Age             0
# City            0
# State           0
# SignupDate     70
# Segment        24
# Acquisition    55
# dtype: int64

# %%
customers["Segment"] = customers["Segment"].fillna("Unknown")

# %%
customers["Acquisition"] = customers["Acquisition"].fillna("Unknown")

# %%
customers["Name"] = customers["Name"].fillna("Unknown")

# %%
customers.isna().sum()
#keeping missing SignupDate values as NaN because the actual signup date cannot be reliably determined
# Out:
# CustomerID      0
# Name            0
# Gender          0
# Age             0
# City            0
# State           0
# SignupDate     70
# Segment         0
# Acquisition     0
# dtype: int64

# %%
customers = customers.drop_duplicates()

# %%
customers["CustomerID"].duplicated().sum()
# Out:
# np.int64(60)

# %%
customers[customers["CustomerID"].duplicated(keep=False)].sort_values("CustomerID")
# Out:
#       CustomerID             Name  Gender  Age         City        State  \
# 448      C000449       Isha Kumar  Female   28  Bhubaneswar  Bhubaneswar
# 12006    C000449    Isha Kumar Jr  Female   28  Bhubaneswar  Bhubaneswar
# 540      C000541      Nisha Yadav  Female   37    Bengaluru    Bengaluru
# 12018    C000541   Nisha Yadav Jr  Female   37    Bengaluru    Bengaluru
# 814      C000815    Vivaan Kapoor  Female   41       Nagpur       Nagpur
# ...          ...              ...     ...  ...          ...          ...
# 11327    C011328     Ananya Kumar    Male   32    Ahmedabad    Ahmedabad
# 12042    C011478     Varun Das Jr  Female   28   Chandigarh   Chandigarh
# 11477    C011478        Varun Das  Female   28   Chandigarh   Chandigarh
# 11613    C011614        Tanya Das    Male   18        Surat        Surat
# 12117    C011614     Tanya Das Jr    Male   18        Surat        Surat
#
#       SignupDate     Segment   Acquisition
# 448   2023-06-10    Consumer   Paid Search
# ...

# %%
customers["Name"] = customers["Name"].str.replace(
    r"\s+Jr\.?$", 
    "", 
    regex=True
)

# %%
customers = customers.drop_duplicates()

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 12030 entries, 0 to 12116
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerID   12030 non-null  str
#  1   Name         12030 non-null  str
#  2   Gender       12030 non-null  str
#  3   Age          12030 non-null  int64
#  4   City         12030 non-null  str
#  5   State        12030 non-null  str
#  6   SignupDate   11960 non-null  datetime64[us]
#  7   Segment      12030 non-null  str
#  8   Acquisition  12030 non-null  str
# dtypes: datetime64[us](1), int64(1), str(7)
# memory usage: 939.8 KB

# %%
customers["CustomerID"].duplicated().sum()
# Out:
# np.int64(30)

# %%
customers[
    customers["CustomerID"].duplicated(keep=False)
].sort_values("CustomerID")
# Out:
#       CustomerID            Name   Gender  Age         City        State  \
# 814      C000815   Vivaan Kapoor   Female   41       Nagpur       Nagpur
# 12084    C000815   Vivaan Kapoor   Female   41       Nagpur       Nagpur
# 1502     C001503    Meera Mishra     Male   31       Jaipur       Jaipur
# 12076    C001503    Meera Mishra     Male   31       Jaipur       Jaipur
# 1729     C001730  Priya Malhotra     Male   29        Delhi        Delhi
# 12092    C001730  Priya Malhotra     Male   29        Delhi        Delhi
# 2077     C002078     Ishaan Bose   Female   25       Bhopal       Bhopal
# 12044    C002078     Ishaan Bose   Female   25       Bhopal       Bhopal
# 2133     C002134  Varun Malhotra   Female   18    Ahmedabad    Ahmedabad
# 12048    C002134  Varun Malhotra   Female   18    Ahmedabad    Ahmedabad
# 12036    C002852    Ananya Joshi     Male   22       Indore       Indore
# 2851     C002852    Ananya Joshi     Male   22       Indore       Indore
# ...

# %%
customers = customers.drop_duplicates(
    subset="CustomerID",
    keep="first"
)

# %%
customers["CustomerID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
customers["SignupDate"].max()
# Out:
# Timestamp('2027-01-15 00:00:00')

# %%
(customers["SignupDate"] > pd.Timestamp("2026-08-14")).sum()
# Out:
# np.int64(42)

# %%
customers.loc[customers["SignupDate"] > "2026-08-14", "SignupDate"] = pd.NaT
#replaced invalid future signup dates with NaT because signup dates cannot be beyond the dataset's reporting date (14-Aug-2026)

# %%
customers["SignupDate"].max()
# Out:
# Timestamp('2026-07-31 00:00:00')

# %%
customers.isna().sum()
# Out:
# CustomerID       0
# Name             0
# Gender           0
# Age              0
# City             0
# State            0
# SignupDate     112
# Segment          0
# Acquisition      0
# dtype: int64

# %%
customers["City"]= customers["City"].str.title()

# %%
customers["State"]= customers["State"].str.title()

# %%
customers["Segment"]= customers["Segment"].str.title()

# %%
customers["Segment"].value_counts()
# Out:
# Segment
# Consumer          7322
# Corporate         2048
# Home Office       1553
# Small Business     944
# Corp                29
# Consumr             28
# Homeoffice          27
# Small Biz           26
# Unknown             23
# Name: count, dtype: int64

# %%
customers["Segment"] = customers["Segment"].replace("Corp" , "Corporate")

# %%
customers["Segment"] = customers["Segment"].replace("CONSUMER" , "Consumer")

# %%
customers["Segment"] = customers["Segment"].replace("consumer" , "Consumer")

# %%
customers["Segment"] = customers["Segment"].replace("Consumr" , "Consumer")

# %%
customers["Segment"] = customers["Segment"].replace("HomeOffice" , "Home Office")

# %%
customers["Segment"] = customers["Segment"].replace("Small Biz" , "Small Business")

# %%
customers["Segment"] = customers["Segment"].replace("Homeoffice" , "Home Office")

# %%
customers["Segment"].value_counts()
# Out:
# Segment
# Consumer          7350
# Corporate         2077
# Home Office       1580
# Small Business     970
# Unknown             23
# Name: count, dtype: int64

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 12000 entries, 0 to 11999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerID   12000 non-null  str
#  1   Name         12000 non-null  str
#  2   Gender       12000 non-null  str
#  3   Age          12000 non-null  int64
#  4   City         12000 non-null  str
#  5   State        12000 non-null  str
#  6   SignupDate   11888 non-null  datetime64[us]
#  7   Segment      12000 non-null  str
#  8   Acquisition  12000 non-null  str
# dtypes: datetime64[us](1), int64(1), str(7)
# memory usage: 937.5 KB

# %%
customers["Acquisition"].value_counts()
# Out:
# Acquisition
# Organic Search    2880
# Social Media      2345
# Paid Search       2251
# Referral          1318
# Marketplace       1238
# Email             1151
# Affiliate          627
# Unknown             55
# market place        34
# PAID SEARCH         26
# organic search      25
# E-mail              20
# social              18
# Referal             12
# Name: count, dtype: int64

# %%
customers["Acquisition"] = customers["Acquisition"].replace("market place","Marketplace")

# %%
customers["Acquisition"] = customers["Acquisition"].replace("Referal","Referral")

# %%
customers["Acquisition"] = customers["Acquisition"].replace("Referal","Referral")

# %%
customers["Acquisition"] = customers["Acquisition"].replace("social","Social Media")

# %%
customers["Acquisition"] = customers["Acquisition"].replace("E-mail","Email")

# %%
customers["Acquisition"] = customers["Acquisition"].replace("organic search","Organic Search")

# %%
customers["Acquisition"] = customers["Acquisition"].replace("PAID SEARCH","Paid Search")

# %%
customers["Acquisition"].value_counts()
# Out:
# Acquisition
# Organic Search    2905
# Social Media      2363
# Paid Search       2277
# Referral          1330
# Marketplace       1272
# Email             1171
# Affiliate          627
# Unknown             55
# Name: count, dtype: int64

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 12000 entries, 0 to 11999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerID   12000 non-null  str
#  1   Name         12000 non-null  str
#  2   Gender       12000 non-null  str
#  3   Age          12000 non-null  int64
#  4   City         12000 non-null  str
#  5   State        12000 non-null  str
#  6   SignupDate   11888 non-null  datetime64[us]
#  7   Segment      12000 non-null  str
#  8   Acquisition  12000 non-null  str
# dtypes: datetime64[us](1), int64(1), str(7)
# memory usage: 937.5 KB

# %%
customers["State"].str.startswith(" ").sum()
# Out:
# np.int64(42)

# %%
customers["State"]= customers["State"].str.strip()

# %%
customers["State"].str.startswith(" ").sum()
# Out:
# np.int64(0)

# %%
customers["State"].str.endswith(" ").sum()
# Out:
# np.int64(0)

# %%
customers["City"].str.startswith(" ").sum()
# Out:
# np.int64(42)

# %%
customers["City"]= customers["City"].str.strip()

# %%
customers["City"].str.startswith(" ").sum()
# Out:
# np.int64(0)

# %%
customers["City"].str.endswith(" ").sum()
# Out:
# np.int64(0)

# %%
customers["Segment"].str.startswith(" ").sum()
# Out:
# np.int64(0)

# %%
customers["Segment"].str.endswith(" ").sum()
# Out:
# np.int64(0)

# %%
customers["Acquisition"].str.startswith(" ").sum()
# Out:
# np.int64(0)

# %%
customers["Acquisition"].str.endswith(" ").sum()
# Out:
# np.int64(0)

# %%
customers["Name"].str.startswith(" ").sum()
# Out:
# np.int64(57)

# %%
customers["Name"] = customers["Name"].str.strip()

# %%
customers["Name"].str.startswith(" ").sum()
# Out:
# np.int64(0)

# %%
customers["Name"].str.endswith(" ").sum()
# Out:
# np.int64(0)

# %%
customers["Gender"].str.endswith(" ").sum()
# Out:
# np.int64(0)

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
age_median = customers["Age"].median()

# %%
age_median
# Out:
# np.float64(34.0)

# %%
invalid_age = (
    (customers["Age"] < 18) |
    (customers["Age"] > 100)
)
invalid_age.value_counts()
# Out:
# Age
# False    11896
# True       104
# Name: count, dtype: int64

# %%
customers.loc[invalid_age, "Age"] = age_median

# %%
customers[customers["Age"] < 18]
# Out:
# Empty DataFrame
# Columns: [CustomerID, Name, Gender, Age, City, State, SignupDate, Segment, Acquisition]
# Index: []

# %%
customers[customers["Age"] > 100]
# Out:
# Empty DataFrame
# Columns: [CustomerID, Name, Gender, Age, City, State, SignupDate, Segment, Acquisition]
# Index: []

# %%
customers_clean_data = customers.copy()

# %%
customers_clean_data.to_csv("customers_clean_data.csv",index=False)

# %%
orders.head()
# Out:
#     OrderID CustomerID   OrderDate PaymentMethod OrderStatus DeliveryDate  \
# 0  O0000001    C005491  2023-02-27           UPI   Cancelled          NaN
# 1  O0000002    C009711  2025-09-23   Credit Card   Delivered   2025-10-01
# 2  O0000003    C006489  2025-02-05   Credit Card   Delivered   2025-02-06
# 3  O0000004    C008378  2024-05-25   Credit Card   Delivered   2024-05-31
# 4  O0000005    C000540  2023-10-16        Wallet   Delivered   2023-10-23
#
#   ShippingCost
# 0         0.00
# 1        70.11
# 2         0.00
# 3        94.32
# 4         0.00

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32320 entries, 0 to 32319
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderID        32320 non-null  str
#  1   CustomerID     32290 non-null  str
#  2   OrderDate      32284 non-null  str
#  3   PaymentMethod  32297 non-null  str
#  4   OrderStatus    32293 non-null  str
#  5   DeliveryDate   27758 non-null  str
#  6   ShippingCost   32270 non-null  str
# dtypes: str(7)
# memory usage: 1.7 MB

# %%
orders["OrderDate"] = pd.to_datetime(
    orders["OrderDate"],
    format="mixed",
    errors="coerce"
)

# %%
orders["DeliveryDate"] = pd.to_datetime(
    orders["DeliveryDate"],
    format="mixed",
    errors="coerce"
)

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32320 entries, 0 to 32319
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderID        32320 non-null  str
#  1   CustomerID     32290 non-null  str
#  2   OrderDate      32204 non-null  datetime64[us]
#  3   PaymentMethod  32297 non-null  str
#  4   OrderStatus    32293 non-null  str
#  5   DeliveryDate   27719 non-null  datetime64[us]
#  6   ShippingCost   32270 non-null  str
# dtypes: datetime64[us](2), str(5)
# memory usage: 1.7 MB

# %%
orders.duplicated().sum()
# Out:
# np.int64(171)

# %%
orders = orders.drop_duplicates()

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders["OrderID"].duplicated().sum()
# Out:
# np.int64(149)

# %%
orders[
    orders["OrderID"].duplicated(keep=False)
].sort_values("OrderID")
# Out:
#         OrderID CustomerID  OrderDate     PaymentMethod OrderStatus  \
# 7      O0000008    C002594 2026-05-15       Credit Card   Cancelled
# 32099  O0000008    C002594 2026-05-15               UPI   Cancelled
# 106    O0000107    C004307 2024-06-15       Net Banking   Delivered
# 32105  O0000107    C004307 2024-06-15               UPI   Delivered
# 506    O0000507    C002141 2024-12-15            Wallet   Delivered
# ...         ...        ...        ...               ...         ...
# 32312  O0031716    C003156 2023-12-09               UPI   Cancelled
# 31755  O0031756    C002465 2023-04-26               UPI   Delivered
# 32168  O0031756    C002465 2023-04-26  Cash on Delivery   Delivered
# 32282  O0031910    C002336 2026-03-05               UPI   Delivered
# 31909  O0031910    C002336 2026-03-05            Wallet   Delivered
#
#       DeliveryDate ShippingCost
# 7              NaT       158.05
# 32099          NaT       158.05
# 106     2024-06-23         1.68
# ...

# %%
orders = orders.drop_duplicates(
    subset="OrderID",
    keep="first"
)

# %%
orders["OrderID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
orders.isnull().sum()
# Out:
# OrderID             0
# CustomerID         30
# OrderDate         115
# PaymentMethod      23
# OrderStatus        27
# DeliveryDate     4545
# ShippingCost       50
# dtype: int64

# %%
orders = orders.dropna(subset=["CustomerID"])

# %%
orders = orders.dropna(subset=["OrderDate"])

# %%
orders
# Out:
#         OrderID CustomerID  OrderDate PaymentMethod OrderStatus DeliveryDate  \
# 0      O0000001    C005491 2023-02-27           UPI   Cancelled          NaT
# 1      O0000002    C009711 2025-09-23   Credit Card   Delivered   2025-10-01
# 2      O0000003    C006489 2025-02-05   Credit Card   Delivered   2025-02-06
# 3      O0000004    C008378 2024-05-25   Credit Card   Delivered   2024-05-31
# 4      O0000005    C000540 2023-10-16        Wallet   Delivered   2023-10-23
# ...         ...        ...        ...           ...         ...          ...
# 31995  O0031996    C006164 2024-05-03           UPI   Delivered   2024-05-08
# 31996  O0031997    C007448 2023-06-23    Debit Card   Delivered   2023-06-29
# 31997  O0031998    C000465 2024-12-04   Credit Card   Delivered   2024-12-11
# 31998  O0031999    C002230 2024-11-02           UPI   Delivered   2024-11-09
# 31999  O0032000    C003082 2024-09-29           UPI   Delivered   2024-10-03
#
#       ShippingCost
# 0             0.00
# ...

# %%
orders["PaymentMethod"].value_counts(dropna=False)
# Out:
# PaymentMethod
# UPI                 9778
# Credit Card         6625
# Cash on Delivery    5431
# Debit Card          4101
# Net Banking         3186
# Wallet              2515
# wallet                28
# CreditCard            27
# upi                   25
# Cash                  25
# debit card            24
# COD                   24
# Crypto                23
# NaN                   23
# NetBanking            20
# Name: count, dtype: int64

# %%
orders["PaymentMethod"] = orders["PaymentMethod"].str.title()

# %%
orders["PaymentMethod"].value_counts(dropna=False)
# Out:
# PaymentMethod
# Upi                 9803
# Credit Card         6625
# Cash On Delivery    5431
# Debit Card          4125
# Net Banking         3186
# Wallet              2515
# Wallet                28
# Creditcard            27
# Cash                  25
# Cod                   24
# Crypto                23
# NaN                   23
# Netbanking            20
# Name: count, dtype: int64

# %%
orders["PaymentMethod"] = orders["PaymentMethod"].replace("Creditcard", "Credit Card")

# %%
orders["PaymentMethod"] = orders["PaymentMethod"].replace("Cash", "Cash On Delivery")

# %%
orders["PaymentMethod"] = orders["PaymentMethod"].replace("Cod", "Cash On Delivery")

# %%
orders["PaymentMethod"] = orders["PaymentMethod"].replace("Netbanking", "Net Banking")

# %%
orders["PaymentMethod"].value_counts(dropna=False)
# Out:
# PaymentMethod
# Upi                 9803
# Credit Card         6652
# Cash On Delivery    5480
# Debit Card          4125
# Net Banking         3206
# Wallet              2515
# Wallet                28
# Crypto                23
# NaN                   23
# Name: count, dtype: int64

# %%
orders["PaymentMethod"] = orders["PaymentMethod"].fillna("Unknown")

# %%
orders["PaymentMethod"] = orders["PaymentMethod"].str.strip()

# %%
orders["PaymentMethod"].value_counts(dropna=False)
# Out:
# PaymentMethod
# Upi                 9803
# Credit Card         6652
# Cash On Delivery    5480
# Debit Card          4125
# Net Banking         3206
# Wallet              2543
# Crypto                23
# Unknown               23
# Name: count, dtype: int64

# %%
orders["PaymentMethod"] = orders["PaymentMethod"].str.title()

# %%
orders["PaymentMethod"].value_counts(dropna=False)
# Out:
# PaymentMethod
# Upi                 9803
# Credit Card         6652
# Cash On Delivery    5480
# Debit Card          4125
# Net Banking         3206
# Wallet              2543
# Crypto                23
# Unknown               23
# Name: count, dtype: int64

# %%
orders["OrderStatus"].value_counts(dropna=False)
# Out:
# OrderStatus
# Delivered      25296
# Cancelled       2516
# Returned        1631
# Shipped         1559
# Processing       633
# delivered         34
# Return            32
# In Transit        29
# NaN               27
# Canceled          27
# processing        27
# Unknown           22
# DELIVERED         22
# Name: count, dtype: int64

# %%
orders["OrderStatus"] = orders["OrderStatus"].str.title()

# %%
orders["OrderStatus"].value_counts(dropna=False)
# Out:
# OrderStatus
# Delivered      25352
# Cancelled       2516
# Returned        1631
# Shipped         1559
# Processing       633
# Return            32
# In Transit        29
# NaN               27
# Canceled          27
# Processing        27
# Unknown           22
# Name: count, dtype: int64

# %%
orders["OrderStatus"] = orders["OrderStatus"].replace("Return","Returned")

# %%
orders["OrderStatus"] = orders["OrderStatus"].replace("Canceled","Cancelled")

# %%
orders["OrderStatus"] = orders["OrderStatus"].str.strip()

# %%
orders["OrderStatus"].value_counts(dropna=False)
# Out:
# OrderStatus
# Delivered     25352
# Cancelled      2543
# Returned       1663
# Shipped        1559
# Processing      660
# In Transit       29
# NaN              27
# Unknown          22
# Name: count, dtype: int64

# %%
orders["OrderStatus"] = orders["OrderStatus"].fillna("Unknown")

# %%
orders["OrderStatus"].value_counts(dropna=False)
# Out:
# OrderStatus
# Delivered     25352
# Cancelled      2543
# Returned       1663
# Shipped        1559
# Processing      660
# Unknown          49
# In Transit       29
# Name: count, dtype: int64

# %%
(orders["DeliveryDate"] > "2026-08-14").sum()
# Out:
# np.int64(37)

# %%
orders.loc[orders["DeliveryDate"] > "2026-08-14", "DeliveryDate"] = pd.NaT

# %%
(orders["DeliveryDate"] > "2026-08-14").sum()
# Out:
# np.int64(0)

# %%
orders.isnull().sum()
# Out:
# OrderID             0
# CustomerID          0
# OrderDate           0
# PaymentMethod       0
# OrderStatus         0
# DeliveryDate     4556
# ShippingCost       49
# dtype: int64

# %%
orders[orders["DeliveryDate"].isna()]["OrderStatus"].value_counts()
# Out:
# OrderStatus
# Cancelled     2517
# Shipped       1247
# Processing     637
# Delivered      133
# Returned        14
# Unknown          6
# In Transit       2
# Name: count, dtype: int64

# %%
orders.loc[
    orders["DeliveryDate"].isna() &
    (orders["OrderStatus"] == "Delivered"),
    "DeliveryDate"
] = pd.NaT

# %%
orders.isnull().sum()
# Out:
# OrderID             0
# CustomerID          0
# OrderDate           0
# PaymentMethod       0
# OrderStatus         0
# DeliveryDate     4556
# ShippingCost       49
# dtype: int64

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 31855 entries, 0 to 31999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderID        31855 non-null  str
#  1   CustomerID     31855 non-null  str
#  2   OrderDate      31855 non-null  datetime64[us]
#  3   PaymentMethod  31855 non-null  str
#  4   OrderStatus    31855 non-null  str
#  5   DeliveryDate   27299 non-null  datetime64[us]
#  6   ShippingCost   31806 non-null  str
# dtypes: datetime64[us](2), str(5)
# memory usage: 1.9 MB

# %%
orders["ShippingCost"] = pd.to_numeric(
    orders["ShippingCost"],
    errors="coerce"
)

# %%
orders["ShippingCost"] = orders["ShippingCost"].fillna(
    orders["ShippingCost"].median()
)

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 31855 entries, 0 to 31999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderID        31855 non-null  str
#  1   CustomerID     31855 non-null  str
#  2   OrderDate      31855 non-null  datetime64[us]
#  3   PaymentMethod  31855 non-null  str
#  4   OrderStatus    31855 non-null  str
#  5   DeliveryDate   27299 non-null  datetime64[us]
#  6   ShippingCost   31855 non-null  float64
# dtypes: datetime64[us](2), float64(1), str(4)
# memory usage: 1.9 MB

# %%
(orders["OrderDate"] > "2026-08-31").sum()
# Out:
# np.int64(48)

# %%
orders.loc[
    orders["OrderDate"] > "2026-08-14",
    "OrderDate"
] = pd.NaT

# %%
(orders["OrderDate"] > "2026-08-31").sum()
# Out:
# np.int64(0)

# %%
orders.loc[orders["ShippingCost"] < 0, "ShippingCost"] = np.nan

# %%
orders["ShippingCost"] = orders["ShippingCost"].fillna(
    orders["ShippingCost"].median()
)

# %%
(orders["ShippingCost"] < 0).sum()
# Out:
# np.int64(0)

# %%
orders["OrderID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
orders_clean_data = orders.copy()

# %%
orders_clean_data.to_csv("orders_clean_data.csv",index=False)

# %%
sales.head()
# Out:
#   OrderItemID   OrderID ProductID Quantity UnitPrice Discount GrossSales  \
# 0  OI00000001  O0029046    P00422        4   4318.82     0.00   17275.28
# 1  OI00000002  O0017104    P01523        1  12291.71     0.05   12291.71
# 2  OI00000003  O0000452    P01327        5   3653.38     0.40   18266.90
# 3  OI00000004  O0010615    P01023        1  11547.81     0.00   11547.81
# 4  OI00000005  O0010012    P01086        1  16442.06     0.20   16442.06
#
#   DiscountAmount  NetSales      Tax TotalCost   Profit
# 0           0.00  17275.28  2073.03   9079.08  8196.20
# 1         614.59  11677.12  2101.88   8751.62  2925.50
# 2        7306.76  10960.14  1972.83  10480.25   479.89
# 3           0.00  11547.81  2078.61   6372.36  5175.45
# 4        3288.41  13153.65  2367.66   9885.70  3267.95

# %%
sales.isna().sum()
# Out:
# OrderItemID         0
# OrderID           124
# ProductID         137
# Quantity          100
# UnitPrice         238
# Discount           98
# GrossSales        224
# DiscountAmount    240
# NetSales          227
# Tax               166
# TotalCost         226
# Profit            418
# dtype: int64

# %%
sales.duplicated().sum()
# Out:
# np.int64(375)

# %%
sales=sales.drop_duplicates()

# %%
sales["OrderItemID"].duplicated().sum()
# Out:
# np.int64(125)

# %%
sales[
    sales["OrderItemID"].duplicated(keep=False)
].sort_values("OrderItemID")
# Out:
#       OrderItemID   OrderID ProductID Quantity UnitPrice Discount GrossSales  \
# 384    OI00000385  O0022323    P00928        1  27675.92     0.00   27675.92
# 99932  OI00000385  O0022323    P00928        2  27675.92     0.00   27675.92
# 99556  OI00002170  O0010112    P00010        2  11085.62     0.20   11085.62
# 2169   OI00002170  O0010112    P00010        1  11085.62     0.20   11085.62
# 2225   OI00002226  O0007303    P00583        2    585.96     0.05    1171.92
# ...           ...       ...       ...      ...       ...      ...        ...
# 98056  OI00098057  O0013847    P00267        1   5747.16     0.10    5747.16
# 98581  OI00098582  O0027839    P01547        1    806.57     0.00     806.57
# 99500  OI00098582  O0027839    P01547        2    806.57     0.00     806.57
# 99724  OI00098776  O0012942    P00983        2   5249.72     0.05   20998.88
# 98775  OI00098776  O0012942    P00983        4   5249.72     0.05   20998.88
#
# ...

# %%
sales = sales.drop_duplicates("OrderItemID")

# %%
sales["Quantity"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
sales["Quantity"] = pd.to_numeric(
    sales["Quantity"],
    errors="coerce"
)

# %%
sales["Quantity"] = sales["Quantity"].astype("Int64")

# %%
sales["Quantity"] = sales["Quantity"].astype("Int64")

# %%
sales["Quantity"].isna().sum()
# Out:
# np.int64(176)

# %%
sales.dtypes
# Out:
# OrderItemID         str
# OrderID             str
# ProductID           str
# Quantity          Int64
# UnitPrice           str
# Discount            str
# GrossSales          str
# DiscountAmount      str
# NetSales            str
# Tax                 str
# TotalCost           str
# Profit              str
# dtype: object

# %%
numeric_cols = [
    "UnitPrice",
    "Discount",
    "GrossSales",
    "DiscountAmount",
    "NetSales",
    "Tax",
    "TotalCost",
    "Profit"
]

for col in numeric_cols:
    sales[col] = pd.to_numeric(
        sales[col],
        errors="coerce"
    )

# %%
sales = sales.dropna(subset=["Quantity"])

# %%
sales[sales["Quantity"] == 0 ]
# Out:
#       OrderItemID   OrderID ProductID  Quantity  UnitPrice  Discount  \
# 682    OI00000683  O0000585    P00683         0    8331.25      0.25
# 1348   OI00001349  O0030154    P01235         0    2007.71      0.20
# 4350   OI00004351  O0002255    P01162         0     850.35      0.15
# 5199   OI00005200  O0031914    P01843         0    1321.52      0.00
# 6461   OI00006462  O0002077    P00537         0    1660.88      0.00
# ...           ...       ...       ...       ...        ...       ...
# 96004  OI00096005  O0031455    P01932         0     824.32      0.00
# 97710  OI00097711  O0005957    P01519         0    1506.21      0.25
# 97734  OI00097735  O0024819    P00681         0    3066.16      0.20
# 98104  OI00098105  O0025361    P00447         0    3951.38      0.20
# 99148  OI00099149  O0009389    P01682         0   25861.98      0.30
#
#        GrossSales  DiscountAmount  NetSales      Tax  TotalCost   Profit
# ...

# %%
sales = sales[sales["Quantity"] > 0]

# %%
sales[sales["UnitPrice"] <= 0]
# Out:
#       OrderItemID   OrderID ProductID  Quantity  UnitPrice  Discount  \
# 59     OI00000060  O0028270    P01065         3     -999.0      0.05
# 435    OI00000436  O0030628    P00722         2        0.0      0.30
# 815    OI00000816  O0000313    P00437         4     -999.0      0.10
# 1921   OI00001922  O0026989    P01861         3     -999.0      0.20
# 2138   OI00002139  O0026773    P01243         2     -999.0      0.00
# ...           ...       ...       ...       ...        ...       ...
# 94342  OI00094343  O0000151    P00741         4        0.0      0.10
# 94886  OI00094887  O0002032    P00422         2     -999.0      0.20
# 96712  OI00096713  O0006041    P01903         2        0.0      0.05
# 97991  OI00097992  O0028572    P01610         2        0.0      0.00
# 98893  OI00098894  O0022956    P00469         3     -999.0      0.00
#
#        GrossSales  DiscountAmount  NetSales      Tax  TotalCost   Profit
# ...

# %%
sales["UnitPrice"].isna().sum()
# Out:
# np.int64(522)

# %%
sales[sales["Discount"] < 0]
# Out:
#       OrderItemID   OrderID ProductID  Quantity  UnitPrice  Discount  \
# 91     OI00000092  O0000340    P00821         2     778.11      -0.1
# 2108   OI00002109  O0014002    P00693         2    2039.64      -0.1
# 2637   OI00002638  O0009839    P01091         1     800.48      -0.1
# 2790   OI00002791  O0009375    P00350         3     847.32      -0.1
# 3110   OI00003111  O0019768    P00119         2     553.91      -0.1
# ...           ...       ...       ...       ...        ...       ...
# 97637  OI00097638  O0005513    P00059         1    2731.41      -0.1
# 98390  OI00098391  O0000068    P01156         1    2710.42      -0.1
# 98536  OI00098537  O0008228    P00460         1    1733.01      -0.1
# 99406  OI00099407  O0002619    P01880         2    1313.12      -0.1
# 99454  OI00099455  O0017182    P01477         2    2057.49      -0.1
#
#        GrossSales  DiscountAmount  NetSales     Tax  TotalCost   Profit
# ...

# %%
sales["Discount"].isna().sum()
# Out:
# np.int64(403)

# %%
sales
# Out:
#       OrderItemID   OrderID ProductID  Quantity  UnitPrice  Discount  \
# 0      OI00000001  O0029046    P00422         4    4318.82      0.00
# 1      OI00000002  O0017104    P01523         1   12291.71      0.05
# 2      OI00000003  O0000452    P01327         5    3653.38      0.40
# 3      OI00000004  O0010615    P01023         1   11547.81      0.00
# 4      OI00000005  O0010012    P01086         1   16442.06      0.20
# ...           ...       ...       ...       ...        ...       ...
# 99495  OI00099496  O0013372    P00709         4   10688.56      0.00
# 99496  OI00099497  O0022603    P01982         3    7031.25      0.05
# 99497  OI00099498  O0003190    P01143         1    4070.18      0.00
# 99498  OI00099499  O0024514    P00766         1   13456.98      0.00
# 99499  OI00099500  O0013234    P01945         3     951.61      0.10
#
#        GrossSales  DiscountAmount  NetSales      Tax  TotalCost    Profit
# ...

# %%
sales["GrossSales"].isna().sum()
# Out:
# np.int64(450)

# %%
sales["GrossSales"] = sales["GrossSales"].fillna(
    sales["Quantity"] * sales["UnitPrice"]
)

# %%
sales["GrossSales"].isna().sum()
# Out:
# np.int64(2)

# %%
sales["UnitPrice"].isna().sum()
# Out:
# np.int64(522)

# %%
check = np.isclose(
    sales["GrossSales"],
    sales["Quantity"] * sales["UnitPrice"],
    atol=0.01
)

np.unique(check, return_counts=True)
# Out:
# (array([False,  True]), array([ 1264, 97773]))

# %%
sales["GrossSales"] = sales["Quantity"] * sales["UnitPrice"]

# %%
check = np.isclose(
    sales["GrossSales"],
    sales["Quantity"] * sales["UnitPrice"],
    atol=0.01
)

np.unique(check, return_counts=True)
# Out:
# (array([False,  True]), array([  522, 98515]))

# %%
sales["DiscountAmount"].isna().sum()
# Out:
# np.int64(410)

# %%
(sales["DiscountAmount"] == 0).sum()
# Out:
# np.int64(29526)

# %%
(sales["DiscountAmount"] < 0).sum()
# Out:
# np.int64(37)

# %%
sales[sales["DiscountAmount"] < 0][
    ["Quantity", "UnitPrice", "GrossSales", "DiscountAmount","NetSales"]
].head(20)
# Out:
#        Quantity  UnitPrice  GrossSales  DiscountAmount  NetSales
# 13495         1   17634.63    17634.63          -37.50  17634.63
# 15622         3    8389.82    25169.46          -37.50  25169.46
# 24736         1     265.88      265.88          -37.50    265.88
# 24755         1    1507.17     1507.17          -37.50   1507.17
# 26331         1    1383.15     1383.15          -37.50   1383.15
# 28936         2    2676.08     5352.16          -37.50   5352.16
# 29177         2   16283.69    32567.38          -37.50  32567.38
# 30680       100    1199.40    119940.0          -37.50   2398.80
# 32042         4     645.10      2580.4          -37.50   2580.40
# 34139         4    3768.66    15074.64          -37.50  15074.64
# 34369         1    2885.13     2885.13          -37.50   2885.13
# 34895         4    1247.68     4990.72          -37.50   4990.72
# 34909         4    7343.84    29375.36          -37.50  29375.36
# ...

# %%
sales["ExpectedDiscountAmount"] = (
    sales["GrossSales"] * sales["Discount"]
)

# %%
check = np.isclose(
    sales["DiscountAmount"],
    sales["ExpectedDiscountAmount"],
    atol=0.01
)

np.unique(check, return_counts=True)
# Out:
# (array([False,  True]), array([ 2352, 96685]))

# %%
sales["Discount"].value_counts().sort_index()
# Out:
# Discount
# -0.10        98
#  0.00     29422
#  0.05      9846
#  0.10     17678
#  0.15     11656
#  0.20     12854
#  0.25      6824
#  0.30      6986
#  0.40      2972
#  1.25       111
#  10.00       97
#  15.00       90
# Name: count, dtype: int64

# %%
sales[sales["Discount"] > 0.40][
    ["GrossSales", "Discount", "DiscountAmount", "NetSales"]
].head(20)
# Out:
#       GrossSales  Discount  DiscountAmount  NetSales
# 668       1680.0      1.25            0.00   1680.00
# 691      3042.55      1.25            0.00   3042.55
# 731      3081.86      1.25            0.00   3081.86
# 965      8788.88      1.25            0.00   8788.88
# 1140     1313.38      1.25          197.01   1116.37
# 1400     4150.22     15.00          830.04   3320.18
# 2042     5434.73     10.00         2173.89   3260.84
# 2063    45505.56      1.25         6825.83  38679.73
# 2137    23497.95      1.25         2349.80  21148.15
# 2323      629.34      1.25           94.40    534.94
# 2336      3510.7      1.25          702.14   2808.56
# 2476     3805.08     10.00          190.25   3614.83
# 3345     7478.25     15.00         1495.65   5982.60
# 3465    14361.82      1.25         2872.36  11489.46
# 4549      1930.9      1.25           96.55   1834.35
# 5613      678.22     10.00          271.29    406.93
# 6289    22519.46     10.00         4503.89  18015.57
# ...

# %%
sales = sales[sales["Discount"] <= 0.40].copy()

# %%
sales[sales["Discount"] > 0.40][
    ["GrossSales", "Discount", "DiscountAmount", "NetSales"]
].head(20)
# Out:
# Empty DataFrame
# Columns: [GrossSales, Discount, DiscountAmount, NetSales]
# Index: []

# %%
sales["DiscountAmount"] = (
    sales["GrossSales"] * sales["Discount"]
)

# %%
check = np.isclose(
    sales["DiscountAmount"],
    sales["GrossSales"] * sales["Discount"],
    atol=0.01
)

check.all()
# Out:
# np.False_

# %%
sales["ExpectedNetSales"] = (
    sales["GrossSales"] - sales["DiscountAmount"]
)

# %%
check = np.isclose(
    sales["NetSales"],
    sales["ExpectedNetSales"],
    atol=0.01
)

np.unique(check, return_counts=True)
# Out:
# (array([False,  True]), array([ 1879, 96457]))

# %%
sales[sales["NetSales"].isna()]
# Out:
#       OrderItemID   OrderID ProductID  Quantity  UnitPrice  Discount  \
# 98     OI00000099  O0008491    P01725         1     856.30      0.10
# 681    OI00000682  O0029929    P01959         1   20952.60      0.15
# 697    OI00000698  O0030789    P00648         1    2848.62      0.20
# 770    OI00000771  O0013378    P01601         1    1081.37      0.20
# 1038   OI00001039  O0014823    P00774         4    8840.88      0.00
# ...           ...       ...       ...       ...        ...       ...
# 98073  OI00098074  O0019494    P00906         2    8357.73      0.10
# 98182  OI00098183  O0001196    P01121         5    1317.59      0.40
# 98347  OI00098348  O0015620    P00847         1    3504.63      0.10
# 98650  OI00098651  O0023007    P00508         1    2261.10      0.30
# 99162  OI00099163  O0014593    P00044         1    5216.61      0.30
#
#        GrossSales  DiscountAmount  NetSales      Tax  TotalCost    Profit  \
# ...

# %%
sales["NetSales"] = (
    sales["GrossSales"] - sales["DiscountAmount"]
)

# %%
check = np.isclose(
    sales["NetSales"],
    sales["ExpectedNetSales"],
    atol=0.01
)

np.unique(check, return_counts=True)
# Out:
# (array([False,  True]), array([  520, 97816]))

# %%
sales["Tax"].isna().sum()
# Out:
# np.int64(244)

# %%
(sales["Tax"] < 0).sum()
# Out:
# np.int64(102)

# %%
sales[
    ["NetSales", "Tax"]
].head(20)
# Out:
#       NetSales      Tax
# 0     17275.28  2073.03
# 1   11677.1245  2101.88
# 2     10960.14  1972.83
# 3     11547.81  2078.61
# 4    13153.648  2367.66
# 5      3530.37   635.47
# 6     8761.064   438.05
# 7      3678.38   183.92
# 8     1970.555   236.47
# 9     6574.974  1183.49
# 10   7792.7645  1402.70
# 11      3363.7   605.47
# 12      611.24   110.02
# 13     13488.8  2427.98
# 14     2900.61   348.07
# 15     1560.75   187.29
# 16   1173.1455   140.78
# 17    3301.706   594.31
# 18    4530.152   815.43
# 19      2849.0   341.88

# %%
sales[sales["Tax"].isna()][
    ["NetSales", "Tax"]
].head(20)
# Out:
#          NetSales  Tax
# 340       8767.77  NaN
# 944       5774.06  NaN
# 1521     4818.684  NaN
# 2028      15901.3  NaN
# 2805    6415.5495  NaN
# 4883      586.432  NaN
# 5366     10811.75  NaN
# 6084      85928.1  NaN
# 6499      5234.68  NaN
# 6757    21165.816  NaN
# 7438      588.642  NaN
# 7636    73456.848  NaN
# 8061     11738.76  NaN
# 8277      614.227  NaN
# 8480     1148.835  NaN
# 8683     1085.776  NaN
# 9135     1324.215  NaN
# 10487    9211.296  NaN
# 10570      551.54  NaN
# 10968  21985.2325  NaN

# %%
sales[sales["Tax"].isna()][
    ["NetSales", "Tax", "TotalCost", "Profit"]
].head(20)
# Out:
#          NetSales  Tax  TotalCost    Profit
# 340       8767.77  NaN    5919.75   2848.02
# 944       5774.06  NaN    3428.99   2345.07
# 1521     4818.684  NaN    3324.51   1494.17
# 2028      15901.3  NaN   12166.66   3734.64
# 2805    6415.5495  NaN    3723.18   2692.37
# 4883      586.432  NaN     620.63    -34.20
# 5366     10811.75  NaN    7098.30   3713.45
# 6084      85928.1  NaN   45190.14  40737.96
# 6499      5234.68  NaN    3204.00   2030.68
# 6757    21165.816  NaN   17327.81   3838.01
# 7438      588.642  NaN     362.57    226.07
# 7636    73456.848  NaN   46033.50  27423.35
# 8061     11738.76  NaN    7553.04   4185.72
# 8277      614.227  NaN     390.62    223.61
# 8480     1148.835  NaN     823.58    325.25
# 8683     1085.776  NaN     661.84    423.94
# 9135     1324.215  NaN     973.06    351.16
# 10487    9211.296  NaN    7419.72   1791.58
# 10570      551.54  NaN     413.24    138.30
# 10968  21985.2325  NaN   16473.93   5511.30

# %%
sales[sales["Tax"] < 0][
    ["NetSales", "Tax", "TotalCost", "Profit"]
].head(20)
# Out:
#          NetSales   Tax  TotalCost   Profit
# 694     15066.243 -50.0   12680.10  2386.14
# 2205      7513.92 -50.0    4080.12  3433.80
# 2755       278.25 -50.0     163.12   115.13
# 2894     13212.45 -50.0    8762.10  4450.35
# 3602     6884.244 -50.0    4806.00  2078.24
# 3655    3949.5015 -50.0    3068.14   881.36
# 3912    5149.0705 -50.0    3958.68  1190.39
# 5775     210.5365 -50.0     161.41    49.13
# 6568     2354.534 -50.0    1556.92   797.61
# 8072      1227.52 -50.0    1129.24    98.28
# 8082      8623.34 -50.0    5434.98  3188.36
# 8245      955.157 -50.0     689.61   265.55
# 8328     1048.964 -50.0     831.40   217.56
# 9309    10975.829 -50.0    6393.52  4582.31
# 9393      9145.57 -50.0    6880.38  2265.19
# 11908    11187.18 -50.0    7807.08  3380.10
# 12764     6214.64 -50.0    3252.78  2961.86
# 14950     2362.49 -50.0    2015.93   346.56
# 15632    7302.944 -50.0    6828.24   474.70
# 16768  13129.8265 -50.0    8906.03  4223.80

# %%
sales.loc[sales["Tax"] < 0, "Tax"] = np.nan

# %%
(sales["Tax"] < 0).sum()
# Out:
# np.int64(0)

# %%
sales["Tax"].isna().sum()
# Out:
# np.int64(346)

# %%
sales["TotalCost"].isna().sum()
# Out:
# np.int64(431)

# %%
(sales["TotalCost"] < 0).sum()
# Out:
# np.int64(0)

# %%
(sales["TotalCost"] == 0).sum()
# Out:
# np.int64(0)

# %%
sales[
    ["NetSales", "Tax", "TotalCost", "Profit"]
].head(20)
# Out:
#       NetSales      Tax  TotalCost   Profit
# 0     17275.28  2073.03    9079.08  8196.20
# 1   11677.1245  2101.88    8751.62  2925.50
# 2     10960.14  1972.83   10480.25   479.89
# 3     11547.81  2078.61    6372.36  5175.45
# 4    13153.648  2367.66    9885.70  3267.95
# 5      3530.37   635.47    2736.98   793.39
# 6     8761.064   438.05    6369.73  2391.33
# 7      3678.38   183.92    1755.12  1923.26
# 8     1970.555   236.47    1811.70   158.85
# 9     6574.974  1183.49    4549.26  2025.71
# 10   7792.7645  1402.70    4316.54  3476.22
# 11      3363.7   605.47    2705.66   658.04
# 12      611.24   110.02     419.94   191.30
# 13     13488.8  2427.98    9445.10  4043.70
# 14     2900.61   348.07    2271.69   628.92
# 15     1560.75   187.29    1267.45   293.30
# 16   1173.1455   140.78     968.43   204.72
# 17    3301.706   594.31    1896.08  1405.63
# 18    4530.152   815.43    3341.89  1188.26
# 19      2849.0   341.88    2458.64   390.36

# %%
sales["ExpectedProfit"] = (
    sales["NetSales"] - sales["TotalCost"]
)

# %%
check = np.isclose(
    sales["Profit"],
    sales["ExpectedProfit"],
    atol=0.01
)

np.unique(check, return_counts=True)
# Out:
# (array([False,  True]), array([ 2843, 95493]))

# %%
sales["Profit"] = sales["NetSales"] - sales["TotalCost"]

# %%
check = np.isclose(
    sales["Profit"],
    sales["NetSales"] - sales["TotalCost"],
    atol=0.01
)

np.unique(check, return_counts=True)
# Out:
# (array([False,  True]), array([  950, 97386]))

# %%
(sales["Profit"] < 0).sum()
# Out:
# np.int64(6385)

# %%
check = np.isclose(
    sales["Profit"],
    sales["NetSales"] - sales["TotalCost"],
    atol=0.01
)

check[sales["TotalCost"].notna()].all()
# Out:
# np.False_

# %%
sales_clean_data = sales.copy()

# %%
sales_clean_data
# Out:
#       OrderItemID   OrderID ProductID  Quantity  UnitPrice  Discount  \
# 0      OI00000001  O0029046    P00422         4    4318.82      0.00
# 1      OI00000002  O0017104    P01523         1   12291.71      0.05
# 2      OI00000003  O0000452    P01327         5    3653.38      0.40
# 3      OI00000004  O0010615    P01023         1   11547.81      0.00
# 4      OI00000005  O0010012    P01086         1   16442.06      0.20
# ...           ...       ...       ...       ...        ...       ...
# 99495  OI00099496  O0013372    P00709         4   10688.56      0.00
# 99496  OI00099497  O0022603    P01982         3    7031.25      0.05
# 99497  OI00099498  O0003190    P01143         1    4070.18      0.00
# 99498  OI00099499  O0024514    P00766         1   13456.98      0.00
# 99499  OI00099500  O0013234    P01945         3     951.61      0.10
#
#        GrossSales  DiscountAmount    NetSales      Tax  TotalCost     Profit  \
# ...

# %%
money_columns = [
    "UnitPrice",
    "GrossSales",
    "DiscountAmount",
    "NetSales",
    "Tax",
    "TotalCost",
    "Profit"
]

sales[money_columns] = sales[money_columns].round(2)

# %%
sales_clean_data.to_csv("sales_clean_data.csv",index = False)

# %%
sales_clean_data = sales.copy()

# %%
sales_clean_data
# Out:
#       OrderItemID   OrderID ProductID  Quantity  UnitPrice  Discount  \
# 0      OI00000001  O0029046    P00422         4    4318.82      0.00
# 1      OI00000002  O0017104    P01523         1   12291.71      0.05
# 2      OI00000003  O0000452    P01327         5    3653.38      0.40
# 3      OI00000004  O0010615    P01023         1   11547.81      0.00
# 4      OI00000005  O0010012    P01086         1   16442.06      0.20
# ...           ...       ...       ...       ...        ...       ...
# 99495  OI00099496  O0013372    P00709         4   10688.56      0.00
# 99496  OI00099497  O0022603    P01982         3    7031.25      0.05
# 99497  OI00099498  O0003190    P01143         1    4070.18      0.00
# 99498  OI00099499  O0024514    P00766         1   13456.98      0.00
# 99499  OI00099500  O0013234    P01945         3     951.61      0.10
#
#        GrossSales  DiscountAmount  NetSales      Tax  TotalCost    Profit  \
# ...

# %%
columns = [
    "ExpectedGrossSales",
    "ExpectedDiscountAmount",
    "ExpectedNetSales",
    "ExpectedProfit"
]

sales_clean_data.drop(columns=columns, inplace=True, errors="ignore")

# %%
sales_clean_data.to_csv("sales_clean_data.csv",index = False)

# %%
products.head()
# Out:
#   ProductID             ProductName          Category  Subcategory   Brand  \
# 0    P00001     Zenova Outdoor B366  Sports & Fitness      Outdoor  Zenova
# 1    P00002      Echo Footwear C863           Fashion     FOOTWEAR    Echo
# 2    P00003  Kairo Non-Fiction D326             Books  Non-Fiction   Kairo
# 3    P00004  Aster Smartphones E615       Electronics  Smartphones   Aster
# 4    P00005       Echo Bedding F477    Home & Kitchen      Bedding    Echo
#
#   CostPrice SellingPrice Rating
# 0   1788.18      2507.17    3.9
# 1    845.18      1328.42    4.0
# 2    373.60       480.82    4.1
# 3  11102.85     22999.99    4.0
# 4   1502.75      3092.52    3.9

# %%
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2030 entries, 0 to 2029
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     2030 non-null   str
#  1   ProductName   2010 non-null   str
#  2   Category      2018 non-null   str
#  3   Subcategory   2006 non-null   str
#  4   Brand         2011 non-null   str
#  5   CostPrice     2011 non-null   str
#  6   SellingPrice  2010 non-null   str
#  7   Rating        1999 non-null   str
# dtypes: str(8)
# memory usage: 127.0 KB

# %%
products["Category"].value_counts()
# Out:
# Category
# Electronics         376
# Fashion             343
# Home & Kitchen      305
# Beauty              239
# Sports & Fitness    195
# Appliances          186
# Books               151
# Grocery             146
# FASHION              17
# Home and Kitchen     17
# Appliance            15
# sports               11
# Electrnics            9
# electronics           8
# Name: count, dtype: int64

# %%
products["Category"] = products["Category"].str.title()

# %%
products["Category"] = products["Category"].replace("Home And Kitchen","Home & Kitchen")

# %%
products["Category"] = products["Category"].replace("sports","Sports & Fitness")

# %%
products["Category"] = products["Category"].replace("Electrnics","Electronics")

# %%
products["Category"] = products["Category"].replace("Sports","Sports & Fitness")

# %%
products["Category"].value_counts()
# Out:
# Category
# Electronics         393
# Fashion             360
# Home & Kitchen      322
# Beauty              239
# Sports & Fitness    206
# Appliances          186
# Books               151
# Grocery             146
# Appliance            15
# Name: count, dtype: int64

# %%
products["Category"] = products["Category"].replace("Appliance","Appliances")

# %%
products["Category"].value_counts()
# Out:
# Category
# Electronics         393
# Fashion             360
# Home & Kitchen      322
# Beauty              239
# Sports & Fitness    206
# Appliances          201
# Books               151
# Grocery             146
# Name: count, dtype: int64

# %%
products["Subcategory"].value_counts()
# Out:
# Subcategory
# Laptops           84
# Headphones        84
# Smart Watches     83
# Women Clothing    77
# Men Clothing      72
#                   ..
# OUTDOOR            1
# smart watches      1
# PersonalCare       1
# cooling            1
# packaged food      1
# Name: count, Length: 87, dtype: int64

# %%
products["Subcategory"] = products["Subcategory"].str.title()

# %%
products["Subcategory"].value_counts()
# Out:
# Subcategory
# Laptops                  86
# Headphones               84
# Smart Watches            84
# Women Clothing           81
# Men Clothing             74
# Footwear                 70
# Accessories              70
# Bedding                  66
# Storage                  66
# Bags                     64
# Watches                  63
# Furniture                61
# Home Decor               60
# Smartphones              58
# Hair Care                57
# Cookware                 53
# Home Appliances          47
# Makeup                   47
# Personal Care            46
# Skin Care                46
# Sportswear               45
# Fragrance                44
# Packaged Food            43
# Yoga                     42
# Fitness Equipment        42
# Outdoor                  37
# Cooling                  37
# Children                 37
# Kitchen Appliances       37
# Non-Fiction              36
# Nutrition Accessories    35
# Small Appliances         34
# ...

# %%
products["Subcategory"] = products["Subcategory"].str.strip()

# %%
products["Subcategory"].value_counts()
# Out:
# Subcategory
# Laptops                  86
# Headphones               85
# Smart Watches            85
# Women Clothing           81
# Men Clothing             76
# Accessories              72
# Footwear                 70
# Storage                  68
# Bedding                  66
# Watches                  64
# Bags                     64
# Furniture                61
# Home Decor               60
# Smartphones              58
# Hair Care                58
# Cookware                 53
# Sportswear               47
# Home Appliances          47
# Makeup                   47
# Personal Care            46
# Skin Care                46
# Fragrance                44
# Packaged Food            43
# Yoga                     42
# Fitness Equipment        42
# Outdoor                  38
# Cooling                  38
# Children                 38
# Kitchen Appliances       37
# Non-Fiction              36
# Nutrition Accessories    35
# Small Appliances         34
# ...

# %%
products["Subcategory"] = products["Subcategory"].replace({
    "Menclothing": "Men Clothing",
    "Nutritionaccessories": "Nutrition Accessories",
    "Personalcare": "Personal Care"
})

# %%
products["ProductName"] = products["ProductName"].str.strip()

# %%
products["Brand"] = products["Brand"].str.strip()

# %%
products["Brand"] = products["Brand"].str.title()

# %%
products["Brand"].value_counts()
# Out:
# Brand
# Urbanpeak       123
# Mira            107
# Nova            106
# Zenova          105
# Aster           105
# Vistara         105
# Zenix           104
# Solace          103
# Nexa            102
# Bluearc         102
# Kairo           101
# Echo             97
# Mintleaf         96
# Rivon            95
# Primenest        95
# Cresta           95
# Altura           92
# Orbito           89
# Vertex           88
# Luma             84
# Unknownbrand     17
# Name: count, dtype: int64

# %%
products["Brand"] = products["Brand"].replace(
    "Unknownbrand", "Unknown"
)

# %%
products.duplicated().sum()
# Out:
# np.int64(30)

# %%
products = products.drop_duplicates()

# %%
products.duplicated().sum()
# Out:
# np.int64(0)

# %%
products.head(5)
# Out:
#   ProductID             ProductName          Category  Subcategory   Brand  \
# 0    P00001     Zenova Outdoor B366  Sports & Fitness      Outdoor  Zenova
# 1    P00002      Echo Footwear C863           Fashion     Footwear    Echo
# 2    P00003  Kairo Non-Fiction D326             Books  Non-Fiction   Kairo
# 3    P00004  Aster Smartphones E615       Electronics  Smartphones   Aster
# 4    P00005       Echo Bedding F477    Home & Kitchen      Bedding    Echo
#
#   CostPrice SellingPrice Rating
# 0   1788.18      2507.17    3.9
# 1    845.18      1328.42    4.0
# 2    373.60       480.82    4.1
# 3  11102.85     22999.99    4.0
# 4   1502.75      3092.52    3.9

# %%
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     2000 non-null   str
#  1   ProductName   1980 non-null   str
#  2   Category      1988 non-null   str
#  3   Subcategory   1976 non-null   str
#  4   Brand         1981 non-null   str
#  5   CostPrice     1981 non-null   str
#  6   SellingPrice  1980 non-null   str
#  7   Rating        1969 non-null   str
# dtypes: str(8)
# memory usage: 125.1 KB

# %%
numeric_cols = ["CostPrice", "SellingPrice", "Rating"]

products[numeric_cols] = products[numeric_cols].apply(
    pd.to_numeric, errors="coerce"
)

# %%
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     2000 non-null   str
#  1   ProductName   1980 non-null   str
#  2   Category      1988 non-null   str
#  3   Subcategory   1976 non-null   str
#  4   Brand         1981 non-null   str
#  5   CostPrice     1951 non-null   float64
#  6   SellingPrice  1956 non-null   float64
#  7   Rating        1959 non-null   float64
# dtypes: float64(3), str(5)
# memory usage: 125.1 KB

# %%
products[numeric_cols].isnull().sum()
# Out:
# CostPrice       49
# SellingPrice    44
# Rating          41
# dtype: int64

# %%
products["Rating"] = products["Rating"].fillna(
    products.groupby("Subcategory")["Rating"].transform("median")
)

# %%
products[numeric_cols].isnull().sum()
# Out:
# CostPrice       49
# SellingPrice    44
# Rating           0
# dtype: int64

# %%
products[(products["Rating"] < 1) | (products["Rating"] > 5)]
# Out:
#      ProductID                        ProductName          Category  \
# 25      P00026                Vistara Makeup A528            Beauty
# 26      P00027             Mira Personal Care B93            Beauty
# 189     P00190  Solace Nutrition Accessories I199  Sports & Fitness
# 237     P00238               Zenix Breakfast E241           Grocery
# 297     P00298                Altura Storage M440    Home & Kitchen
# 331     P00332          UrbanPeak Accessories U93       Electronics
# 375     P00376                 zenix bedding m562    Home & Kitchen
# 417     P00418          Orbito Packaged Food C946           Grocery
# 449     P00450                  Mira Watches I578           Fashion
# 473     P00474           Cresta Men Clothing G835           Fashion
# 480     P00481               Nexa Headphones N781       Electronics
# 521     P00522               Luma Home Decor C670    Home & Kitchen
# 577     P00578           Rivon Smart Watches G721       Electronics
# ...

# %%
products.loc[
    (products["Rating"] < 1) | (products["Rating"] > 5),
    "Rating"
] = np.nan

# %%
products["Rating"] = products["Rating"].fillna(
    products.groupby("Subcategory")["Rating"].transform("median")
)

# %%
products[
    products["CostPrice"].isnull() | products["SellingPrice"].isnull()
]
# Out:
#      ProductID                    ProductName          Category  \
# 23      P00024          UrbanPeak Fiction Y45             Books
# 54      P00055   UrbanPeak Personal Care D857            Beauty
# 55      P00056      Orbito Smart Watches E155       Electronics
# 59      P00060   Aster Fitness Equipment I918  Sports & Fitness
# 128     P00129           Zenova Academic Z242             Books
# ...        ...                            ...               ...
# 1872    P01873             Zenova Fiction B46             Books
# 1921    P01922        Echo Smart Watches Y390       Electronics
# 1941    P01942         UrbanPeak Storage S871    Home & Kitchen
# 1951    P01952  Cresta-Fitness-Equipment-C645  Sports & Fitness
# 1970    P01971           BlueArc Laptops V245       Electronics
#
#             Subcategory      Brand  CostPrice  SellingPrice  Rating
# 23              Fiction  Urbanpeak     645.18           NaN     3.3
# ...

# %%
products["CostPrice"] = products["CostPrice"].fillna(
    products.groupby("Subcategory")["CostPrice"].transform("median")
)

# %%
products[
    products["CostPrice"].isnull() | products["SellingPrice"].isnull()
]
# Out:
#      ProductID                       ProductName          Category  \
# 23      P00024             UrbanPeak Fiction Y45             Books
# 54      P00055      UrbanPeak Personal Care D857            Beauty
# 159     P00160         Orbito Packaged Food E477           Grocery
# 228     P00229               Zenova Outdoor V724  Sports & Fitness
# 251     P00252      PrimeNest Smart Watches S803       Electronics
# 337     P00338               Vistara Makeup A327            Beauty
# 428     P00429               Altura Watches N223           Fashion
# 523     P00524            Kairo Non-Fiction E590             Books
# 524     P00525           Vistara Headphones F588       Electronics
# 563     P00564                Luma Cookware S446    Home & Kitchen
# 565     P00566      Vistara Home Appliances U337        Appliances
# 581     P00582            PrimeNest Laptops K115       Electronics
# 596     P00597            UrbanPeak Cookware Z25    Home & Kitchen
# ...

# %%
products["CostPrice"] = products["CostPrice"].fillna(
    products["CostPrice"].median()
)

# %%
products["SellingPrice"] = products["SellingPrice"].fillna(
    products.groupby("Subcategory")["SellingPrice"].transform("median")
)

# %%
products["SellingPrice"] = products["SellingPrice"].fillna(
    products["SellingPrice"].median()
)

# %%
products[["CostPrice", "SellingPrice"]].isnull().sum()
# Out:
# CostPrice       0
# SellingPrice    0
# dtype: int64

# %%
(products["CostPrice"] < 0).sum()
# Out:
# np.int64(17)

# %%
products.loc[products["CostPrice"] < 0, "CostPrice"] = np.nan

# %%
products["CostPrice"] = products["CostPrice"].fillna(
    products.groupby("Subcategory")["CostPrice"].transform("median")
)

# %%
(products["CostPrice"] < 0).sum()
# Out:
# np.int64(0)

# %%
(products["SellingPrice"] < 0).sum()
# Out:
# np.int64(15)

# %%
products.loc[products["SellingPrice"] < 0, "SellingPrice"] = np.nan

# %%
products["SellingPrice"] = products["SellingPrice"].fillna(
    products.groupby("Subcategory")["SellingPrice"].transform("median")
)

# %%
(products["SellingPrice"] < 0).sum()
# Out:
# np.int64(0)

# %%
products[["Brand", "ProductName","Category","Subcategory",]].isnull().sum()
# Out:
# Brand          19
# ProductName    20
# Category       12
# Subcategory    24
# dtype: int64

# %%
products["Brand"] = products["Brand"].fillna("Unknown")

# %%
products["ProductName"] = products["ProductName"].fillna("Unknown")

# %%
products["Category"] = products["Category"].fillna("Unknown")

# %%
products["Subcategory"] = products["Subcategory"].fillna("Unknown")

# %%
products[["Brand", "ProductName","Category","Subcategory",]].isnull().sum()
# Out:
# Brand          0
# ProductName    0
# Category       0
# Subcategory    0
# dtype: int64

# %%
products["ProductID"].isna().sum()
# Out:
# np.int64(0)

# %%
products["CostPrice"] = products["CostPrice"].round(2)
products["SellingPrice"] = products["SellingPrice"].round(2)
products["Rating"] = products["Rating"].round(1)

# %%
products_clean_data = products.copy()

# %%
products_clean_data.to_csv("products_clean_data.csv", index = False)
